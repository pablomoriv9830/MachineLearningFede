# %% [markdown]
# # Variables numéricas

# %%
1
# Out:
# 1

# %%
mi_numero = 1

# %%
mi_numero + 2
# Out:
# 5

# %%
otro_numero = 2

# %%
otro_numero
# Out:
# 2

# %%
mi_numero + otro_numero
# Out:
# 3

# %%
mi_numero = 3

# %%
mi_numero
# Out:
# 1

# %%
nuevo_numero = 3
